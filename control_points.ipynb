# %%
km_13_dict = {"SW": [7403060.860,	565003.550],
              "NE":	[7403341.550,	565121.170],
              "SW2":	[7403060.860,	565131.500],
              "NE1":	[7403341.520,	565239.150],
              "NE2":	[7403336.850,	565239.150],
              "NE3":	[7403336.850,	565250.480]
              }

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 10))
for key in km_13_dict:
    plt.plot(km_13_dict[key][0], km_13_dict[key][1], 'ro')
    plt.text(km_13_dict[key][0], km_13_dict[key][1], key)
plt.show()
